# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
import time
import numpy as np

# %% [markdown]
# # getCAISOLMP Function

# %%
def getCAISOLMP(startdate="20211228", enddate="20240328", query_name = "PRC_INTVL_LMP", market_run_id="RTM",nodes=["ALL"],version="3"):
    '''
    OASIS URL request examples: https://developer.caiso.com/Artifacts/OASIS/TechSpecs/OASIS%20API%20URL%207.3.0%20Examples.pdf
    Equivalent to OASIS > Prices > Energy Prices > Location Marginal Prices (LMP)
    Equivalent to OASIS > Prices > Energy Prices > Interval Location Marginal Prices (LMP)
    Parameters:
    startdate: string - beginning date
    enddate: string - end date (exclusive)
    query_name: string
        options are "PRC_LMP" and "PRC_INTVL_LMP"        
    market_run_id: string
        options are "DAM" and "RSUC" for LMP
        options are "RTM" for INTVL_LMP
    nodes: string list
        options:
            list of node strings and ["ALL"]
    
    '''
    start = datetime.strptime(startdate,"%Y%m%d")
    end = datetime.strptime(enddate,"%Y%m%d")
  # Initialize data frame with starting day
    activeDay = start
  
  #define base URL
    baseURL = "http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6" #resultformat=6
    if(nodes!=["ALL"]):
        print(nodes)
        data = pd.DataFrame()
        while(activeDay < end):
            nextDay = activeDay +timedelta(days=1)
            j = 300
            for node in nodes:
                j +=1
                activeNode = node  
          # assemble url for LMP
                getURL = baseURL + "&queryname=" + query_name + "&startdatetime=" +  activeDay.strftime("%Y%m%d") + "T08:00-0000" + "&enddatetime=" + nextDay.strftime("%Y%m%d") + "T08:00-0000"+ "&version=" + version + "&market_run_id=" + market_run_id+ "&node=" + activeNode
                #print(getURL)
                r = requests.get(getURL)  
                new_file_name = str(j) + '.zip'
                time.sleep(5)
                with open(new_file_name, 'wb') as f:
                    f.write(r.content)
                partial_data = pd.read_csv(new_file_name)
                data = data.append(partial_data, ignore_index=True)
      
            activeDay = activeDay + timedelta(days=1) # add one day 
    else: #...or get all of the nodes...
    
         #get all nodes day by day.  
        print("all at once")
      # First day -- initialize data output frame.
        activeDay = activeDay + timedelta(days=1)
        getURL = baseURL + "&queryname=" + query_name +"&startdatetime=" + start.strftime("%Y%m%d") + "T08:00-0000"+ "&enddatetime=" + activeDay.strftime("%Y%m%d") + "T00:00-0000"+ "&version=" + version + "&market_run_id="+market_run_id +"&grp_type=ALL_APNODES"
        r = requests.get(getURL)  
        new_file_name = str(start)[:10] + ".zip"
        print(new_file_name)
        with open(new_file_name, 'wb') as f:
            f.write(r.content)
        #data = pd.read_csv('zip_folder.zip')# unzip and read csv, dump into data
        f.close()
        #os.remove('zip_folder.zip')
        k = 1
        while(activeDay < end):
            time.sleep(5)
            nextDay = activeDay +timedelta(days=1)
            getURL = "http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=" + query_name+"&startdatetime=" + activeDay.strftime("%Y%m%d") + "T08:00-0000"+ "&enddatetime=" + nextDay.strftime("%Y%m%d") + "T00:00-0000"+ "&version=" + version + "&market_run_id="+market_run_id +"&grp_type=ALL_APNODES"
            r = requests.get(getURL)  
            new_file_name = str(activeDay)[:10] + '.zip'
            print(new_file_name)
            with open(new_file_name, 'wb') as f:
                f.write(r.content)
            #partial_data = pd.read_csv(new_file_name)# unzip and read csv, dump into data
            #data = pd.concat([data, partial_data], ignore_index=True)
            f.close()
            activeDay = activeDay + timedelta(days=1) #increment one day
            k += 1

# %% [markdown]
# ## Usage Example 1
# Runs the function with all default parameters. Makes a request Prices LMP from Jan 1, 2023 through Jan 3, 2023 with DAM market id for all nodes all at once.

# %%
df1 = getCAISOLMP() # run with all default params
df1
# Out:
# all at once
# 2021-12-28.zip
# 2021-12-29.zip
# 2021-12-30.zip
# 2021-12-31.zip
# 2022-01-01.zip
# 2022-01-02.zip
# 2022-01-03.zip
# 2022-01-04.zip
# 2022-01-05.zip
# 2022-01-06.zip
# 2022-01-07.zip
# 2022-01-08.zip
# 2022-01-09.zip
# 2022-01-10.zip
# 2022-01-11.zip
# 2022-01-12.zip
# 2022-01-13.zip
# 2022-01-14.zip
# 2022-01-15.zip
# 2022-01-16.zip
# 2022-01-17.zip
# 2022-01-18.zip
# 2022-01-19.zip
# 2022-01-20.zip
# 2022-01-21.zip
# 2022-01-22.zip
# 2022-01-23.zip
# 2022-01-24.zip
# 2022-01-25.zip
# 2022-01-26.zip
# 2022-01-27.zip
# 2022-01-28.zip
# 2022-01-29.zip
# 2022-01-30.zip
# 2022-01-31.zip
# 2022-02-01.zip
# 2022-02-02.zip
# 2022-02-03.zip
# 2022-02-04.zip
# 2022-02-05.zip
# 2022-02-06.zip
# 2022-02-07.zip
# 2022-02-08.zip
# 2022-02-09.zip
# 2022-02-10.zip
# 2022-02-11.zip
# 2022-02-12.zip
# 2022-02-13.zip
# 2022-02-14.zip
# 2022-02-15.zip
# 2022-02-16.zip
# 2022-02-17.zip
# 2022-02-18.zip
# 2022-02-19.zip
# 2022-02-20.zip
# 2022-02-21.zip
# 2022-02-22.zip
# 2022-02-23.zip
# 2022-02-24.zip
# 2022-02-25.zip
# 2022-02-26.zip
# 2022-02-27.zip
# 2022-02-28.zip
# 2022-03-01.zip
# 2022-03-02.zip
# 2022-03-03.zip
# 2022-03-04.zip
# 2022-03-05.zip
# 2022-03-06.zip
# 2022-03-07.zip
# 2022-03-08.zip
# 2022-03-09.zip
# 2022-03-10.zip
# 2022-03-11.zip
# 2022-03-12.zip
# 2022-03-13.zip
# 2022-03-14.zip
# 2022-03-15.zip
# 2022-03-16.zip
# 2022-03-17.zip
# 2022-03-18.zip
# 2022-03-19.zip
# 2022-03-20.zip
# 2022-03-21.zip
# 2022-03-22.zip
# 2022-03-23.zip
# 2022-03-24.zip
# 2022-03-25.zip
# 2022-03-26.zip
# 2022-03-27.zip
# 2022-03-28.zip
# 2022-03-29.zip
# 2022-03-30.zip
# 2022-03-31.zip
# 2022-04-01.zip
# 2022-04-02.zip
# 2022-04-03.zip
# 2022-04-04.zip
# 2022-04-05.zip
# 2022-04-06.zip
# 2022-04-07.zip
# 2022-04-08.zip
# 2022-04-09.zip
# 2024-01-05.zip
# 2024-01-06.zip
# 2024-01-07.zip
# 2024-01-08.zip
# 2024-01-09.zip
# 2024-01-10.zip
# 2024-01-11.zip
# 2024-01-12.zip
# 2024-01-13.zip
# 2024-01-14.zip
# 2024-01-15.zip
# 2024-01-16.zip
# 2024-01-17.zip
# 2024-01-18.zip
# 2024-01-19.zip
# 2024-01-20.zip
# 2024-01-21.zip
# 2024-01-22.zip
# 2024-01-23.zip
# 2024-01-24.zip
# 2024-01-25.zip
# 2024-01-26.zip
# 2024-01-27.zip
# 2024-01-28.zip
# 2024-01-29.zip
# 2024-01-30.zip
# 2024-01-31.zip
# 2024-02-01.zip
# 2024-02-02.zip
# 2024-02-03.zip
# 2024-02-04.zip
# 2024-02-05.zip
# 2024-02-06.zip
# 2024-02-07.zip
# 2024-02-08.zip
# 2024-02-09.zip
# 2024-02-10.zip
# 2024-02-11.zip
# 2024-02-12.zip
# 2024-02-13.zip
# 2024-02-14.zip
# 2024-02-15.zip
# 2024-02-16.zip
# 2024-02-17.zip
# 2024-02-18.zip
# 2024-02-19.zip
# 2024-02-20.zip
# 2024-02-21.zip
# 2024-02-22.zip
# 2024-02-23.zip
# 2024-02-24.zip
# 2024-02-25.zip
# 2024-02-26.zip
# 2024-02-27.zip
# 2024-02-28.zip
# 2024-02-29.zip
# 2024-03-01.zip
# 2024-03-02.zip
# 2024-03-03.zip
# 2024-03-04.zip
# 2024-03-05.zip
# 2024-03-06.zip
# 2024-03-07.zip
# 2024-03-08.zip
# 2024-03-09.zip
# 2024-03-10.zip
# 2024-03-11.zip
# 2024-03-12.zip
# 2024-03-13.zip
# 2024-03-14.zip
# 2024-03-15.zip
# 2024-03-16.zip
# 2024-03-17.zip
# 2024-03-18.zip
# 2024-03-19.zip
# 2024-03-20.zip
# 2024-03-21.zip
# 2024-03-22.zip
# 2024-03-23.zip
# 2024-03-24.zip
# 2024-03-25.zip
# 2024-03-26.zip
# 2024-03-27.zip
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df1.NODE.value_counts()
# Out:
# NODE
# AFPR_1_TOT_GEN-APND         180
# POD_SUNRIS_2_PL1X3-APND     180
# POD_SNMALF_6_UNITS-APND     180
# POD_SPI LI_2_UNIT 1-APND    180
# POD_SPICER_1_UNITS-APND     180
#                            ...
# PGFG_1_PDRP40-APND          180
# PGFG_1_PDRP38-APND          180
# PGFG_1_PDRP37-APND          180
# PGFG_1_PDRP36-APND          180
# YU_6_TGEN-APND              180
# Name: count, Length: 2301, dtype: int64

# %%
# filtering the dataframe to make it easier (only one node and LMP type sorted by time) to see the results
df1[(df1["NODE"]=="POD_GARNET_1_WIND-APND") & (df1["LMP_TYPE"]=="LMP")].sort_values(by=['INTERVALSTARTTIME_GMT'])
# Out:
#             INTERVALSTARTTIME_GMT        INTERVALENDTIME_GMT      OPR_DT  \
# 153621  2023-01-01T08:00:00-00:00  2023-01-01T09:00:00-00:00  2023-01-01
# 153612  2023-01-01T09:00:00-00:00  2023-01-01T10:00:00-00:00  2023-01-01
# 153617  2023-01-01T10:00:00-00:00  2023-01-01T11:00:00-00:00  2023-01-01
# 153618  2023-01-01T11:00:00-00:00  2023-01-01T12:00:00-00:00  2023-01-01
# 153606  2023-01-01T12:00:00-00:00  2023-01-01T13:00:00-00:00  2023-01-01
# ...                           ...                        ...         ...
# 153622  2023-01-04T03:00:00-00:00  2023-01-04T04:00:00-00:00  2023-01-03
# 153604  2023-01-04T04:00:00-00:00  2023-01-04T05:00:00-00:00  2023-01-03
# 153608  2023-01-04T05:00:00-00:00  2023-01-04T06:00:00-00:00  2023-01-03
# 153618  2023-01-04T06:00:00-00:00  2023-01-04T07:00:00-00:00  2023-01-03
# 153605  2023-01-04T07:00:00-00:00  2023-01-04T08:00:00-00:00  2023-01-03
#
#         OPR_HR  OPR_INTERVAL             NODE_ID_XML                 NODE_ID  \
# 153621       1             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 153612       2             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 153617       3             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 153618       4             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 153606       5             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# ...        ...           ...                     ...                     ...
# 153622      20             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 153604      21             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 153608      22             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 153618      23             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 153605      24             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
#
#                           NODE MARKET_RUN_ID LMP_TYPE XML_DATA_ITEM  \
# 153621  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 153612  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 153617  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 153618  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 153606  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# ...                        ...           ...      ...           ...
# 153622  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 153604  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 153608  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 153618  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 153605  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
#
#                  PNODE_RESMRID     GRP_TYPE  POS         MW  GROUP
# 153621  POD_GARNET_1_WIND-APND  ALL_APNODES    0  119.50237   6401
# 153612  POD_GARNET_1_WIND-APND  ALL_APNODES    0  114.00266   6401
# 153617  POD_GARNET_1_WIND-APND  ALL_APNODES    0  113.33344   6401
# 153618  POD_GARNET_1_WIND-APND  ALL_APNODES    0  108.80537   6401
# 153606  POD_GARNET_1_WIND-APND  ALL_APNODES    0  107.75499   6401
# ...                        ...          ...  ...        ...    ...
# 153622  POD_GARNET_1_WIND-APND  ALL_APNODES    0  203.86993   6401
# 153604  POD_GARNET_1_WIND-APND  ALL_APNODES    0  203.80423   6401
# 153608  POD_GARNET_1_WIND-APND  ALL_APNODES    0  195.40220   6401
# 153618  POD_GARNET_1_WIND-APND  ALL_APNODES    0  183.90588   6401
# 153605  POD_GARNET_1_WIND-APND  ALL_APNODES    0  165.43605   6401
#
# [72 rows x 16 columns]

# %% [markdown]
# ## Usage Example 2
# Runs with a list of nodes instead of all at once.

# %%
df2 = getCAISOLMP(startdate="20230101", enddate="20230104", query_name = "PRC_LMP", market_run_id="DAM",nodes=["AFPR_1_TOT_GEN-APND", "POD_GARNET_1_WIND-APND"], version="12")
df2
# Out:
# ['AFPR_1_TOT_GEN-APND', 'POD_GARNET_1_WIND-APND']
# http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&startdatetime=20230101T08:00-0000&enddatetime=20230102T08:00-0000&version=12&market_run_id=DAM&node=AFPR_1_TOT_GEN-APND
# http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&startdatetime=20230101T08:00-0000&enddatetime=20230102T08:00-0000&version=12&market_run_id=DAM&node=POD_GARNET_1_WIND-APND
# http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&startdatetime=20230102T08:00-0000&enddatetime=20230103T08:00-0000&version=12&market_run_id=DAM&node=AFPR_1_TOT_GEN-APND
# http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&startdatetime=20230102T08:00-0000&enddatetime=20230103T08:00-0000&version=12&market_run_id=DAM&node=POD_GARNET_1_WIND-APND
# http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&startdatetime=20230103T08:00-0000&enddatetime=20230104T08:00-0000&version=12&market_run_id=DAM&node=AFPR_1_TOT_GEN-APND
# http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&startdatetime=20230103T08:00-0000&enddatetime=20230104T08:00-0000&version=12&market_run_id=DAM&node=POD_GARNET_1_WIND-APND
#          INTERVALSTARTTIME_GMT        INTERVALENDTIME_GMT      OPR_DT  OPR_HR  \
# 0    2023-01-02T02:00:00-00:00  2023-01-02T03:00:00-00:00  2023-01-01      19
# 1    2023-01-01T08:00:00-00:00  2023-01-01T09:00:00-00:00  2023-01-01       1
# 2    2023-01-01T16:00:00-00:00  2023-01-01T17:00:00-00:00  2023-01-01       9
# 3    2023-01-01T21:00:00-00:00  2023-01-01T22:00:00-00:00  2023-01-01      14
# 4    2023-01-01T09:00:00-00:00  2023-01-01T10:00:00-00:00  2023-01-01       2
# ..                         ...                        ...         ...     ...
# 715  2023-01-04T03:00:00-00:00  2023-01-04T04:00:00-00:00  2023-01-03      20
# 716  2023-01-04T05:00:00-00:00  2023-01-04T06:00:00-00:00  2023-01-03      22
# 717  2023-01-03T10:00:00-00:00  2023-01-03T11:00:00-00:00  2023-01-03       3
# 718  2023-01-03T11:00:00-00:00  2023-01-03T12:00:00-00:00  2023-01-03       4
# 719  2023-01-03T18:00:00-00:00  2023-01-03T19:00:00-00:00  2023-01-03      11
#
#      OPR_INTERVAL             NODE_ID_XML                 NODE_ID  \
# 0               0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 1               0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 2               0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 3               0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 4               0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# ..            ...                     ...                     ...
# 715             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 716             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 717             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 718             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 719             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
#
#                        NODE MARKET_RUN_ID LMP_TYPE XML_DATA_ITEM  \
# 0       AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
# 1       AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
# 2       AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
# 3       AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
# 4       AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
# ..                      ...           ...      ...           ...
# 715  POD_GARNET_1_WIND-APND           DAM     MGHG   LMP_GHG_PRC
# 716  POD_GARNET_1_WIND-APND           DAM     MGHG   LMP_GHG_PRC
# 717  POD_GARNET_1_WIND-APND           DAM     MGHG   LMP_GHG_PRC
# 718  POD_GARNET_1_WIND-APND           DAM     MGHG   LMP_GHG_PRC
# 719  POD_GARNET_1_WIND-APND           DAM     MGHG   LMP_GHG_PRC
#
#               PNODE_RESMRID     GRP_TYPE  POS         MW  GROUP
# 0       AFPR_1_TOT_GEN-APND  ALL_APNODES    0  146.71380      1
# 1       AFPR_1_TOT_GEN-APND  ALL_APNODES    0  118.47953      1
# 2       AFPR_1_TOT_GEN-APND  ALL_APNODES    0  102.23182      1
# 3       AFPR_1_TOT_GEN-APND  ALL_APNODES    0   47.44513      1
# 4       AFPR_1_TOT_GEN-APND  ALL_APNODES    0  113.14323      1
# ..                      ...          ...  ...        ...    ...
# 715  POD_GARNET_1_WIND-APND  ALL_APNODES    0    0.00000      5
# 716  POD_GARNET_1_WIND-APND  ALL_APNODES    0    0.00000      5
# 717  POD_GARNET_1_WIND-APND  ALL_APNODES    0    0.00000      5
# 718  POD_GARNET_1_WIND-APND  ALL_APNODES    0    0.00000      5
# 719  POD_GARNET_1_WIND-APND  ALL_APNODES    0    0.00000      5
#
# [720 rows x 16 columns]

# %%
# filtering the dataframe to make it easier (LMP type sorted by time) to see the results
df2[(df2["LMP_TYPE"]=="LMP")].sort_values(by=['INTERVALSTARTTIME_GMT'])
# Out:
#          INTERVALSTARTTIME_GMT        INTERVALENDTIME_GMT      OPR_DT  OPR_HR  \
# 1    2023-01-01T08:00:00-00:00  2023-01-01T09:00:00-00:00  2023-01-01       1
# 131  2023-01-01T08:00:00-00:00  2023-01-01T09:00:00-00:00  2023-01-01       1
# 126  2023-01-01T09:00:00-00:00  2023-01-01T10:00:00-00:00  2023-01-01       2
# 4    2023-01-01T09:00:00-00:00  2023-01-01T10:00:00-00:00  2023-01-01       2
# 6    2023-01-01T10:00:00-00:00  2023-01-01T11:00:00-00:00  2023-01-01       3
# ..                         ...                        ...         ...     ...
# 485  2023-01-04T05:00:00-00:00  2023-01-04T06:00:00-00:00  2023-01-03      22
# 605  2023-01-04T06:00:00-00:00  2023-01-04T07:00:00-00:00  2023-01-03      23
# 486  2023-01-04T06:00:00-00:00  2023-01-04T07:00:00-00:00  2023-01-03      23
# 619  2023-01-04T07:00:00-00:00  2023-01-04T08:00:00-00:00  2023-01-03      24
# 487  2023-01-04T07:00:00-00:00  2023-01-04T08:00:00-00:00  2023-01-03      24
#
#      OPR_INTERVAL             NODE_ID_XML                 NODE_ID  \
# 1               0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 131             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 126             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 4               0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 6               0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# ..            ...                     ...                     ...
# 485             0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 605             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 486             0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 619             0  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 487             0     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
#
#                        NODE MARKET_RUN_ID LMP_TYPE XML_DATA_ITEM  \
# 1       AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
# 131  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 126  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 4       AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
# 6       AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
# ..                      ...           ...      ...           ...
# 485     AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
# 605  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 486     AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
# 619  POD_GARNET_1_WIND-APND           DAM      LMP       LMP_PRC
# 487     AFPR_1_TOT_GEN-APND           DAM      LMP       LMP_PRC
#
#               PNODE_RESMRID     GRP_TYPE  POS         MW  GROUP
# 1       AFPR_1_TOT_GEN-APND  ALL_APNODES    0  118.47953      1
# 131  POD_GARNET_1_WIND-APND  ALL_APNODES    0  119.50237      1
# 126  POD_GARNET_1_WIND-APND  ALL_APNODES    0  114.00266      1
# 4       AFPR_1_TOT_GEN-APND  ALL_APNODES    0  113.14323      1
# 6       AFPR_1_TOT_GEN-APND  ALL_APNODES    0  112.34070      1
# ..                      ...          ...  ...        ...    ...
# 485     AFPR_1_TOT_GEN-APND  ALL_APNODES    0  185.34460      1
# 605  POD_GARNET_1_WIND-APND  ALL_APNODES    0  183.90588      1
# 486     AFPR_1_TOT_GEN-APND  ALL_APNODES    0  176.50410      1
# 619  POD_GARNET_1_WIND-APND  ALL_APNODES    0  165.43605      1
# 487     AFPR_1_TOT_GEN-APND  ALL_APNODES    0  159.28620      1
#
# [144 rows x 16 columns]

# %% [markdown]
# ## Usage Example 3
# Interval LMP data with list of two nodes.

# %%
df3 = getCAISOLMP(startdate="20230101", enddate="20230103", query_name = "PRC_INTVL_LMP", market_run_id="RTM", nodes=["AFPR_1_TOT_GEN-APND", "POD_GARNET_1_WIND-APND"], version="3")
df3
# Out:
# ['AFPR_1_TOT_GEN-APND', 'POD_GARNET_1_WIND-APND']
# http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_INTVL_LMP&startdatetime=20230101T08:00-0000&enddatetime=20230102T08:00-0000&version=3&market_run_id=RTM&node=AFPR_1_TOT_GEN-APND
# http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_INTVL_LMP&startdatetime=20230101T08:00-0000&enddatetime=20230102T08:00-0000&version=3&market_run_id=RTM&node=POD_GARNET_1_WIND-APND
# http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_INTVL_LMP&startdatetime=20230102T08:00-0000&enddatetime=20230103T08:00-0000&version=3&market_run_id=RTM&node=AFPR_1_TOT_GEN-APND
# http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_INTVL_LMP&startdatetime=20230102T08:00-0000&enddatetime=20230103T08:00-0000&version=3&market_run_id=RTM&node=POD_GARNET_1_WIND-APND
#           INTERVALSTARTTIME_GMT        INTERVALENDTIME_GMT      OPR_DT  \
# 0     2023-01-01T08:00:00-00:00  2023-01-01T08:05:00-00:00  2023-01-01
# 1     2023-01-01T08:05:00-00:00  2023-01-01T08:10:00-00:00  2023-01-01
# 2     2023-01-01T08:10:00-00:00  2023-01-01T08:15:00-00:00  2023-01-01
# 3     2023-01-01T08:15:00-00:00  2023-01-01T08:20:00-00:00  2023-01-01
# 4     2023-01-01T08:20:00-00:00  2023-01-01T08:25:00-00:00  2023-01-01
# ...                         ...                        ...         ...
# 5755  2023-01-03T07:35:00-00:00  2023-01-03T07:40:00-00:00  2023-01-02
# 5756  2023-01-03T07:40:00-00:00  2023-01-03T07:45:00-00:00  2023-01-02
# 5757  2023-01-03T07:45:00-00:00  2023-01-03T07:50:00-00:00  2023-01-02
# 5758  2023-01-03T07:50:00-00:00  2023-01-03T07:55:00-00:00  2023-01-02
# 5759  2023-01-03T07:55:00-00:00  2023-01-03T08:00:00-00:00  2023-01-02
#
#       OPR_HR             NODE_ID_XML                 NODE_ID  \
# 0          1     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 1          1     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 2          1     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 3          1     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# 4          1     AFPR_1_TOT_GEN-APND     AFPR_1_TOT_GEN-APND
# ...      ...                     ...                     ...
# 5755      24  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 5756      24  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 5757      24  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 5758      24  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
# 5759      24  POD_GARNET_1_WIND-APND  POD_GARNET_1_WIND-APND
#
#                         NODE MARKET_RUN_ID LMP_TYPE XML_DATA_ITEM  \
# 0        AFPR_1_TOT_GEN-APND           RTM      MCC  LMP_CONG_PRC
# 1        AFPR_1_TOT_GEN-APND           RTM      MCC  LMP_CONG_PRC
# 2        AFPR_1_TOT_GEN-APND           RTM      MCC  LMP_CONG_PRC
# 3        AFPR_1_TOT_GEN-APND           RTM      MCC  LMP_CONG_PRC
# 4        AFPR_1_TOT_GEN-APND           RTM      MCC  LMP_CONG_PRC
# ...                      ...           ...      ...           ...
# 5755  POD_GARNET_1_WIND-APND           RTM      LMP       LMP_PRC
# 5756  POD_GARNET_1_WIND-APND           RTM      LMP       LMP_PRC
# 5757  POD_GARNET_1_WIND-APND           RTM      LMP       LMP_PRC
# 5758  POD_GARNET_1_WIND-APND           RTM      LMP       LMP_PRC
# 5759  POD_GARNET_1_WIND-APND           RTM      LMP       LMP_PRC
#
#                PNODE_RESMRID     GRP_TYPE  POS     VALUE  OPR_INTERVAL  GROUP
# 0        AFPR_1_TOT_GEN-APND  ALL_APNODES    0    0.0000             1      1
# 1        AFPR_1_TOT_GEN-APND  ALL_APNODES    0    0.0000             2      1
# 2        AFPR_1_TOT_GEN-APND  ALL_APNODES    0    0.0000             3      1
# 3        AFPR_1_TOT_GEN-APND  ALL_APNODES    0    0.0000             4      1
# 4        AFPR_1_TOT_GEN-APND  ALL_APNODES    0    0.0024             5      1
# ...                      ...          ...  ...       ...           ...    ...
# 5755  POD_GARNET_1_WIND-APND  ALL_APNODES    0  149.9988             8      5
# 5756  POD_GARNET_1_WIND-APND  ALL_APNODES    0  149.9968             9      5
# 5757  POD_GARNET_1_WIND-APND  ALL_APNODES    0  148.3800            10      5
# 5758  POD_GARNET_1_WIND-APND  ALL_APNODES    0  146.7492            11      5
# 5759  POD_GARNET_1_WIND-APND  ALL_APNODES    0  148.6700            12      5
#
# [5760 rows x 16 columns]
